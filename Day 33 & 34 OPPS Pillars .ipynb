# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# # 4 Pillars

# %% [markdown]
# ![https___dev-to-uploads.s3.amazonaws.com_uploads_articles_jnjgfl10cn4tm9qlztv1.webp](attachment:74b72367-e58b-43a0-87bc-9e3dbd534d97.webp)

# %%
def engine_start(self):
        pass

# %%
class Car:
    def __init__(self,name): # special method, class constructor
        print(f'Welcome {name} User!!')
        print('🙏🙏')

        # instance variable
        self.wheel = 4
        self.spare_wheel = 1
        self.tool_kit = True
        self.key = 1
        self.engine_power = '400 hp'
        no_of_cylinders = 8

    
    #features:- functional features
    # methods
    def engine_start(self):
        pass

    def brake(self):
        print('Brake func code')

    def change_gear(self):
        pass

    def accelerate(self):
        ...
        
    def horn(self):
        ...

    def auto_pilot_mode(self):
        ...

    def find_me(self):
        ...

    def self_park(self):
        ...

    # def beta_fly_mode(self):
    #     ...

# %%
audi = Car('Audi')
# class : Car
# audi: Object, instance object
# Out:
# Welcome Audi User!!
# 🙏🙏

# %%
bmw = Car('BMW')
# Out:
# Welcome BMW User!!
# 🙏🙏

# %%
tata = Car('ANKIT')
# Out:
# Welcome ANKIT User!!
# 🙏🙏

# %%
honda = Car('HONDA')
# Out:
# Welcome HONDA User!!
# 🙏🙏

# %%
# import pygame
# # pygame.init()

# %%
a = 45

# %%
b = 'hello'

# %%
isinstance(a,str)
# Out:
# False

# %%
isinstance(audi,Car)
# Out:
# True

# %%
type(audi) == Car
# Out:
# True

# %%
audi.engine_power
# Out:
# '400 hp'

# %%
audi.brake()
# Out:
# Brake func code

# %%
audi.key
# Out:
# 1

# %%
audi.tool_kit
# Out:
# True

# %%
audi.engine_power
# Out:
# '600 HP'

# %%
bmw.engine_power
# Out:
# '400 hp'

# %%
honda.engine_power
# Out:
# '400 hp'

# %%
audi.engine_power = '600 HP'

# %%
audi.color = 'Black MATE'

# %%
audi.color
# Out:
# 'Black MATE'

# %%
honda.color
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 honda.color
#
# AttributeError: 'Car' object has no attribute 'color'
