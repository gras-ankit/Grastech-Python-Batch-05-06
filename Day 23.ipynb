# %% [markdown]
# # Function Scope in Python
# # Lamda Func:- Map, Filter, Reduce
# # Recursive Func
# # Generator

# %% [markdown]
# # Function Scope in Python

# %%
def phone_a_friend(name):
    # Function ke andar jo bhi declare hoga wo local scope hoga
    import time
    import random
    c = 1
    print(f'Calling {name.upper()}📞',end = '')
    while c <=5:
        print('.',end = '')
        time.sleep(1)
        c += 1
    print(f'\nThe correct Option is: {random.choice("abcd")}')

# %%
phone_a_friend('naman')
# Out:
# Calling NAMAN📞.....
# The correct Option is: a

# %%
random.choice('abcd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 random.choice('abcd')
#
# NameError: name 'random' is not defined

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
# Global Scope

# %%
n = 'Mohan'

def your_intro():
    print(f'My name is {n}')

# %%
n = 'karan'
your_intro()
# Out:
# My name is karan

# %%
def intro():
    global name
    name = 'Mohan' # local variable
    print(f'My name is {name} Kumar!!')

# %%
intro()
# Out:
# My name is Mohan Kumar!!

# %%
name
# Out:
# 'Mohan'

# %%
# non local

# %%
def msg():
    name = 'India'

    def city_msg():
        nonlocal name
        name = 'Noida'
        print(f'Msg 2: I love {name}')

    city_msg()
    print(f'Msg 1: I Love {name}')

# %%
msg()
# Out:
# Msg 2: I love Noida
# Msg 1: I Love Noida

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# Generator

# %%
def give_one_by_one():
    yield 'Gold Chain'
    yield 'Silver Chain'
    yield 'Iron Chain'
    yield 'Phone'
    yield 'Laptop'

# %%
data = give_one_by_one()

# %%
data
# Out:
# <generator object give_one_by_one at 0x0000023E6621CF60>

# %%
next(data)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 next(data)
#
# StopIteration:

# %%
# Lamda Func:- Map, Filter, Reduce
# Recursive Func

# %%
# Recursive Func:- func calling itself

# %%
t = 1
def call_me():
    global t
    print(f'Calling!! time: {t}')
    t += 1
    call_me()

# %%
call_me()
# Out:
# Calling!! time: 1
# Calling!! time: 2
# Calling!! time: 3
# Calling!! time: 4
# Calling!! time: 5
# Calling!! time: 6
# Calling!! time: 7
# Calling!! time: 8
# Calling!! time: 9
# Calling!! time: 10
# Calling!! time: 11
# Calling!! time: 12
# Calling!! time: 13
# Calling!! time: 14
# Calling!! time: 15
# Calling!! time: 16
# Calling!! time: 17
# Calling!! time: 18
# Calling!! time: 19
# Calling!! time: 20
# Calling!! time: 21
# Calling!! time: 22
# Calling!! time: 23
# Calling!! time: 24
# Calling!! time: 25
# Calling!! time: 26
# Calling!! time: 27
# Calling!! time: 28
# Calling!! time: 29
# Calling!! time: 30
# Calling!! time: 31
# Calling!! time: 32
# Calling!! time: 33
# Calling!! time: 34
# Calling!! time: 35
# Calling!! time: 36
# Calling!! time: 37
# Calling!! time: 38
# Calling!! time: 39
# Calling!! time: 40
# Calling!! time: 41
# Calling!! time: 42
# Calling!! time: 43
# Calling!! time: 44
# Calling!! time: 45
# Calling!! time: 46
# Calling!! time: 47
# Calling!! time: 48
# ...

# %%
#factorial
#  ant
# 'nat'
# 'tna'
# 'atn'
# 'nta'
# 'tan'

# %%
5*4*3*2*1
# Out:
# 120

# %%
# 3!= 
3*2*1
# Out:
# 6

# %%
def facto(n):
    ans = 1
    for i in range(1,n+1):
        ans *= i
    return ans

# %%
facto(40)
# Out:
# 815915283247897734345611269596115894272000000000

# %%
4**4
# Out:
# 256

# %%
# 3/256

# %%
def rec_facto(n):
    if n == 1:
        return n
    else:
        return n*rec_facto(n-1)

# %%
rec_facto(5)
# Out:
# 120

# %%
facto(500)
# Out:
# ...

# %%
# sum_of_n_natural_num

# %%
def rec_sum(n):
    if n == 1:
        return n
    else:
        return rec_sum(n-1)+n

# %%
rec_sum(100)
# Out:
# 5050
