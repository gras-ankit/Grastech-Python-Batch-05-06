# %%
# For loop:- range
# pass, break, continue else

# %%
# continue
import random
emp_id = [235,36,2,35,346,5,52,543,6,567,46,54,7]

bonus = []

for i in emp_id:
    if i in (52,567):
        continue   # skip the iteration and control pass to next loop iteration
    else:
        bonus.append((i,random.randint(100,500)))
        print(f'Emp id : {i}:  <<BONUS Mil gaya>>')
# Out:
# Emp id : 235:  <<BONUS Mil gaya>>
# Emp id : 36:  <<BONUS Mil gaya>>
# Emp id : 2:  <<BONUS Mil gaya>>
# Emp id : 35:  <<BONUS Mil gaya>>
# Emp id : 346:  <<BONUS Mil gaya>>
# Emp id : 5:  <<BONUS Mil gaya>>
# Emp id : 543:  <<BONUS Mil gaya>>
# Emp id : 6:  <<BONUS Mil gaya>>
# Emp id : 46:  <<BONUS Mil gaya>>
# Emp id : 54:  <<BONUS Mil gaya>>
# Emp id : 7:  <<BONUS Mil gaya>>

# %%
print(bonus)
# Out:
# [(235, 357), (36, 229), (2, 387), (35, 489), (346, 403), (5, 121), (543, 324), (6, 427), (46, 239), (54, 129), (7, 421)]

# %%
# continue
import random
emp_id = [235,36,2,35,346,5,52,543,6,567,46,54,7]

bonus = []

for i in emp_id:
    if i in (52,567):
        continue   # skip the iteration and control pass to next loop iteration
        print('MAza aa agya')
    else:
        bonus.append((i,random.randint(100,500)))
        print(f'Emp id : {i}:  <<BONUS Mil gaya>>')
# Out:
# Emp id : 235:  <<BONUS Mil gaya>>
# Emp id : 36:  <<BONUS Mil gaya>>
# Emp id : 2:  <<BONUS Mil gaya>>
# Emp id : 35:  <<BONUS Mil gaya>>
# Emp id : 346:  <<BONUS Mil gaya>>
# Emp id : 5:  <<BONUS Mil gaya>>
# Emp id : 543:  <<BONUS Mil gaya>>
# Emp id : 6:  <<BONUS Mil gaya>>
# Emp id : 46:  <<BONUS Mil gaya>>
# Emp id : 54:  <<BONUS Mil gaya>>
# Emp id : 7:  <<BONUS Mil gaya>>

# %%
# continue
import random
emp_id = [235,36,2,35,346,5,52,543,6,567,46,54,7]

bonus = []

for i in emp_id:
    if i in (52,567):
        pass  # skip the iteration and control pass to next code
        print('maza aa gaya')
    else:
        bonus.append((i,random.randint(100,500)))
        print(f'Emp id : {i}:  <<BONUS Mil gaya>>')
# Out:
# Emp id : 235:  <<BONUS Mil gaya>>
# Emp id : 36:  <<BONUS Mil gaya>>
# Emp id : 2:  <<BONUS Mil gaya>>
# Emp id : 35:  <<BONUS Mil gaya>>
# Emp id : 346:  <<BONUS Mil gaya>>
# Emp id : 5:  <<BONUS Mil gaya>>
# maza aa gaya
# Emp id : 543:  <<BONUS Mil gaya>>
# Emp id : 6:  <<BONUS Mil gaya>>
# maza aa gaya
# Emp id : 46:  <<BONUS Mil gaya>>
# Emp id : 54:  <<BONUS Mil gaya>>
# Emp id : 7:  <<BONUS Mil gaya>>

# %%
import string
import random
bags = ['Books','Pen','Toys','Sharp Object','Knife','Pan masala','Bags',"Bombs",'masala']

items_not_allowed = ['sharp object','knife','pan masala','masala','bombs']

people_database = {}


all_person_names = string.ascii_uppercase

for i in all_person_names:
    people_database['Person_'+i] = random.choice(bags)

# print(people_database)

# %%
print(people_database)
# Out:
# {'Person_A': 'Toys', 'Person_B': 'Pan masala', 'Person_C': 'Toys', 'Person_D': 'Books', 'Person_E': 'Bags', 'Person_F': 'Sharp Object', 'Person_G': 'Knife', 'Person_H': 'Sharp Object', 'Person_I': 'Books', 'Person_J': 'Sharp Object', 'Person_K': 'Books', 'Person_L': 'masala', 'Person_M': 'Sharp Object', 'Person_N': 'masala', 'Person_O': 'Books', 'Person_P': 'Pen', 'Person_Q': 'Toys', 'Person_R': 'Knife', 'Person_S': 'masala', 'Person_T': 'Bombs', 'Person_U': 'Bags', 'Person_V': 'Bags', 'Person_W': 'Books', 'Person_X': 'Knife', 'Person_Y': 'masala', 'Person_Z': 'Sharp Object'}

# %%
import time
for name,item in people_database.items():
    if item.lower() in items_not_allowed:
        print(f'Hello Mr.{name}, You can not check in!!')
        print(f'you have {item}, that\'s why it is not allowed')

        if item.lower() == 'bombs':
            print('❌Emergency Situation❌')
            break    

    else:
        print(f'Welcome Mr.{name}, have a great trip!!')
        path = r"C:\Users\salma\OneDrive\Desktop\people_pic"

        all_pic_name = os.listdir(path)
        pic_path = path + '\\'+ random.choice(all_pic_name)
        
        display(IPython.display.Image(pic_path,width=50,height=50)) 

    

    time.sleep(2)
    display(clear= True)
# Out:
# Hello Mr.Person_T, You can not check in!!
# you have Bombs, that's why it is not allowed
# ❌Emergency Situation❌

# %%
import IPython
IPython.display.Image(r"C:\Users\salma\OneDrive\Desktop\people_pic\5.jpg",width=50,height=50)

# %%
import os

# %%
# for i in os.listdir(path):
#     print(path + '\\'+ i)

# %%
import string
import random
bags = ['Books','Pen','Toys','Sharp Object','Knife','Pan masala','Bags',"Bombs",'masala']

items_not_allowed = ['sharp object','knife','pan masala','masala','bombs']

people_database = {}


all_person_names = string.ascii_uppercase

for i in all_person_names:
    people_database['Person_'+i] = random.choice(bags)

# print(people_database)


 import time
for name,item in people_database.items():
    if item.lower() in items_not_allowed:
        print(f'Hello Mr.{name}, You can not check in!!')
        print(f'you have {item}, that\'s why it is not allowed')

        if item.lower() == 'bombs':
            print('❌Emergency Situation❌')
            break    

    else:
        print(f'Welcome Mr.{name}, have a great trip!!')
        path = r"C:\Users\salma\OneDrive\Desktop\people_pic"

        all_pic_name = os.listdir(path)
        pic_path = path + '\\'+ random.choice(all_pic_name)
        
        display(IPython.display.Image(pic_path,width=50,height=50)) 

    

    time.sleep(2)
    display(clear= True)
